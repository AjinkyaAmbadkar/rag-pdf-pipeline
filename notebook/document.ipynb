# %% [markdown]
# ## Data Ingestion

# %%
# Document DataStructure
from langchain_core.documents import Document
## Just for nicer print 
from pprint import pprint

# %%
doc = Document(
    page_content="This is the sample document created to study the Document structure of LangChain",
    metadata = {
        "source": "example.txt",
        "pages": 1,
        "author": "Ajinkya Ambadkar",
        "date_created": "2026-07-11"

    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Ajinkya Ambadkar', 'date_created': '2026-07-11'}, page_content='This is the sample document created to study the Document structure of LangChain')

# %%
## Create a simple text file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt":"""Beginner's Guide to Python
Welcome to Python.

The official Python tutorial provides a good starting point if you have programmed in another language.

New to programming? Python is free and easy to learn if you know where to start! This guide will help you get started.

Beginner's Guide: Chinese Translation/中文版入门


New to Python?
Read BeginnersGuide/Overview for a short explanation of what Python is.


Getting Python
Next, install the Python 3 interpreter on your computer. This is the program that reads Python programs and carries out their instructions; you need it before you can do any Python programming. Mac and Linux distributions may include an outdated version of Python (Python 2), but you should install an updated one (Python 3). See BeginnersGuide/Download for instructions to download the correct version of Python.

There are also Python interpreter and IDE bundles available, such as Thonny. Other options can be found at IntegratedDevelopmentEnvironments.

At some stage, you'll want to edit and save your program code. Take a look at HowToEditPythonCode for some advice and recommendations.


"""
}

for filepath, content in sample_text.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("Sample text created!")
# Out:
# Sample text created!

# %%
sample_text = {
    "../data/text_files/langchain_intro.txt":"""Welcome to LangChain
Large language models (LLMs) are emerging as a transformative technology, enabling developers to build applications that they previously could not. But using these LLMs in isolation is often not enough to create a truly powerful app - the real power comes when you are able to combine them with other sources of computation or knowledge.

This library is aimed at assisting in the development of those types of applications. Common examples of these types of applications include:

❓ Question Answering over specific documents

Documentation

End-to-end Example: Question Answering over Notion Database

💬 Chatbots

Documentation

End-to-end Example: Chat-LangChain

🤖 Agents

Documentation

End-to-end Example: GPT+WolframAlpha
"""
}

for filepath, content in sample_text.items():
    with open(filepath, 'w', encoding="utf-8") as f:
        f.write(content)

print("Sample text created!")
# Out:
# Sample text created!

# %%
## Text Loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
loader
doc = loader.load()
print(doc)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Beginner's Guide to Python\nWelcome to Python.\n\nThe official Python tutorial provides a good starting point if you have programmed in another language.\n\nNew to programming? Python is free and easy to learn if you know where to start! This guide will help you get started.\n\nBeginner's Guide: Chinese Translation/中文版入门\n\n\nNew to Python?\nRead BeginnersGuide/Overview for a short explanation of what Python is.\n\n\nGetting Python\nNext, install the Python 3 interpreter on your computer. This is the program that reads Python programs and carries out their instructions; you need it before you can do any Python programming. Mac and Linux distributions may include an outdated version of Python (Python 2), but you should install an updated one (Python 3). See BeginnersGuide/Download for instructions to download the correct version of Python.\n\nThere are also Python interpreter and IDE bundles available,
# ...

# %%
## Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## Load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", # Pattern to match for all text files
    loader_cls= TextLoader,  ## Loader class to use
    loader_kwargs={'encoding' : 'utf-8'},
    show_progress= False

)

documents = dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Beginner's Guide to Python\nWelcome to Python.\n\nThe official Python tutorial provides a good starting point if you have programmed in another language.\n\nNew to programming? Python is free and easy to learn if you know where to start! This guide will help you get started.\n\nBeginner's Guide: Chinese Translation/中文版入门\n\n\nNew to Python?\nRead BeginnersGuide/Overview for a short explanation of what Python is.\n\n\nGetting Python\nNext, install the Python 3 interpreter on your computer. This is the program that reads Python programs and carries out their instructions; you need it before you can do any Python programming. Mac and Linux distributions may include an outdated version of Python (Python 2), but you should install an updated one (Python 3). See BeginnersGuide/Download for instructions to download the correct version of Python.\n\nThere are also Python interpreter and IDE bundles available,
# ...

# %%
## Creating PDF folder under data
os.makedirs("../data/pdf_files",exist_ok = False)

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## Load all the PDF files from the directory
dir_loader = DirectoryLoader(
    "../data/pdf_files",
    glob="**/*.pdf", # Pattern to match for all text files
    loader_cls= PyMuPDFLoader,  ## Loader class to use
    show_progress= False

)

pdf_documents = dir_loader.load()
pprint(pdf_documents)
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2020-05-14T00:16:20+00:00', 'source': '../data/pdf_files/ZeROMemoryOptimizations.pdf', 'file_path': '../data/pdf_files/ZeROMemoryOptimizations.pdf', 'total_pages': 24, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2020-05-14T00:16:20+00:00', 'trapped': '', 'modDate': 'D:20200514001620Z', 'creationDate': 'D:20200514001620Z', 'page': 0}, page_content='ZeRO: Memory Optimizations Toward Training Trillion\nParameter Models\nSamyam Rajbhandari∗, JeﬀRasley∗, Olatunji Ruwase, Yuxiong He\n{samyamr, jerasley, olruwase, yuxhe}@microsoft.com\nAbstract\nLarge deep learning models oﬀer signiﬁcant accuracy gains, but training billions to trillions of\nparameters is challenging. Existing solutions such as data and model parallelisms exhibit funda-\nmental limitations to ﬁt these models into limited device memory, while obtaining computation,\ncommu
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ## Data Injestion step is completed here!

# %% [markdown]
# ## Now Chunking Part!
